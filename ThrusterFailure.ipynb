# %%
import time as tm
print(f'Setting up thruster failure scenario.')
tm.sleep(1)
print(f'.')
tm.sleep(1)
print(f'.')
tm.sleep(1)
print(f'.')
tm.sleep(1)
print(f'.')
tm.sleep(1)
print(f'.')
tm.sleep(1)
print(f'Commencing scenario.\nDesignating user as engineer.')
print(f'Engineer, I am detecting a fluid leak in one of the rear thrusters. The thruster has enter emergency stop and is no longer operating.')
# Out:
# Setting up thruster failure scenario.
# .
# .
# .
# .
# .
# Commencing scenario.
# Designating user as engineer.
# Engineer, I am detecting a fluid leak in one of the rear thrusters. The thruster has enter emergency stop and is no longer operating.

# %%
userInput=input()
if ('how' in userInput) or ('damage' in userInput) or('diagnostics' in userInput)or('bad' in userInput):
    print('Main rear thruster beta is currently offline, I am not reading any energy coming from it. However, the ship did record an impact just before failure')
    userInput=input()
    if ('impact' in userInput) or ('What' in userInput) or ('hit' in userInput):
        print('[Readings displayed] Judging by the data, it appears as though a small but fast impact occured destroying one of the fuel lines.')
        userInput=input()
        if ('What' in userInput) or('what' in userInput) or ('possibly' in userInput) or ('could' in userInput):
            print('Long range sensors indicated a small explosion, most likely cause of the impact is a piece of debris or meteorite hurled at us from far away.')
            userInput=input()
            if('Can' in userInput) or ('repair'in userInput) or ('replace'in userInput):
                print('We are currently on approach for an asteroid field, spacewalking is ill-advised.')
                userInput=input()
                if ('What' in userInput) or ('do'in userInput) or ('anything' in userInput):
                    print('There is a backup fuel line I can route until we can find a suitable place to land and do repairs.')
                    userInput=input()
                    if ('that' in userInput) or ('do' in userInput):
                        print('I require authorization, a verbal password is needed. [For the scenario, typed is fine.]')
                        userInput = input()
                        if('igloo13' in userInput) or('Igloo13' in userInput):
                            print('Authorization accepted. Rerouting fuel to emergency line until repairs can be done.')
                            print('[Scenario end. Action is taken by the crew to temporarily repair the thruster.]')
                        else:
                            print('Error, invalid interaction.')
                    else:
                        print('Error, invalid interaction.')
                else:
                    print('Error, invalid interaction.')
            else:
                print('Error, invalid interaction.')
        else:
            print('Error, invalid interaction.')
    elif ('Image' in userInput) or ('image'in userInput) or ('visual' in userInput):
            print('I have very little for visuals but I will display it.')
            print('[Visual is a small blurr going through the fuel line of thruster beta.]')
            userInput =input()
            if ('What' in userInput) or ('what' in userInput)  or ('that' in userInput):
                print('I am unsure however,long range sensors indicated a small explosion, most likely cause of the impact is a piece of debris or meteorite hurled at us from far away.')
                print('This is the most likely cause')
                userInput=input()
                if('Can' in userInput) or ('repair'in userInput) or ('replace'in userInput):
                print('We are currently on approach for an asteroid field, spacewalking is ill-advised.')
                userInput=input()
                    if ('What' in userInput) or ('do'in userInput) or ('anything' in userInput):
                        print('There is a backup fuel line I can route until we can find a suitable place to land and do repairs.')
                        userInput=input()
                        if ('that' in userInput) or ('do' in userInput):
                            print('I require authorization, a verbal password is needed. [For the scenario, typed is fine.]')
                            userInput = input()
                            if('igloo13' in userInput) or('Igloo13' in userInput):
                                print('Authorization accepted. Rerouting fuel to emergency line until repairs can be done.')
                                print('[Scenario end. Action is taken by the crew to temporarily repair the thruster.]')
                            else:
                                print('Error, invalid interaction.')
                        else:
                                print('Error, invalid interaction.')
                    else:
                        print('Error, invalid interaction.')
                else:
                    print('Error, invalid interaction.')
            else:
                print('Error, invalid interaction.')
    else:
        print('Error, invalid interaction.')
else:
    print('Error, invalid interaction.')
