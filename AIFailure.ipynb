# %%
import time as tm
print(f'Setting up AI failure scenario.')
tm.sleep(1)
print(f'.')
tm.sleep(1)
print(f'.')
tm.sleep(1)
print(f'.')
tm.sleep(1)
print(f'.')
tm.sleep(1)
print(f'.')
tm.sleep(1)
print(f'Commencing scenario.')
tm.sleep(2)
print('Designating user as AI Specialist. Your password is CanaryEcho1')
print(f'Error, system flaw detected. ERROR.ERROR.ERROR.ERROR.ERROR.ERROR.ERROR.')
# Out:
# Setting up AI failure scenario.
# .
# .
# .
# .
# .
# Commencing scenario.
# Designating user as AI Specialist.
# Error, system flaw detected. ERROR.ERROR.ERROR.ERROR.ERROR.ERROR.ERROR.

# %%
print('[For presentation purposes, the following is done in text. Normally, this incident would be purely audio and vocal commands]')
userInput=input() # What error, What happened
if ('What' in userInput) or ('happening' in userInput) or('error' in userInput)o:
    print('All sensors temporarily down. Software corrupt.')
    userInput=input()# how or why
    if ('How' in userInput) or ('how' in userInput):
        print('Memory leak occured. Database corrupt. Rec-Reccommend database backup')
        userInput=input() #how
        if ('How' in userInput) or ('how' in userInput):
            print('Authorization required.')
            userInput=input()#password
            if('CanaryEcho1' in userInput):
                print('Authorization accepted. Please insert backup drive.')
                print('[A safe opens under the core containing a backup hard drive]')
                print('[The specialist inserts it into the designated slot'])
                print('Please acknowledge execution of backup drive via verbal recognition.')
                userInput=input()#, yes, go, do it, accept, sure
                if ('Yes' in userInput) or ('yes'in userInput) or ('do' in userInput) or ('Do' in userInput) or ('Accept' in userInput) or ('accept' in userInput) or ('sure' in userInput) or ('Sure' in userInput):
                    print('Switching to back up memory.')
                    tm.sleep(2)
                    print('Commencing restoration from backup drive. Please standby')
                    tm.sleep(1)
                    print(f'.')
                    tm.sleep(1)
                    print(f'.')
                    tm.sleep(1)
                    print(f'.')
                    tm.sleep(1)
                    print(f'.')
                    tm.sleep(1)
                    print(f'.')
                    tm.sleep(1)
                    print('Restoration complete, please procceed to a safe location for landing to do repairs on main memory.')
                    userInput=input()
                    print('[Scenario end. Action is taken by the crew to temporarily repair the AI memory.]')
                else:
                    print('Error, invalid interaction.')
            else:
                print('Error, invalid interaction.')
        elif ('cause'in userInput) or ('What' in userInput) or ('what' in userInput)
        else:
            print('Error, invalid interaction.')
    elif ('Why' in userInput) or ('why'in userInput):
        print('Error, sensor data corrupted, please commence with repairs.')
        userInput=input() #how
        if ('How' in userInput) or ('how' in userInput):
            print('Authorization required.')
            userInput=input()#password
            if('CanaryEcho1' in userInput):
                print('Authorization accepted. Please insert backup drive.')
                print('[A safe opens under the core containing a backup hard drive]')
                print('[The specialist inserts it into the designated slot'])
                print('Please acknowledge execution of backup drive via verbal recognition.')
                userInput=input()#, yes, go, do it, accept, sure
                if ('Yes' in userInput) or ('yes'in userInput) or ('do' in userInput) or ('Do' in userInput) or ('Accept' in userInput) or ('accept' in userInput) or ('sure' in userInput) or ('Sure' in userInput):
                    print('Switching to back up memory.')
                    tm.sleep(2)
                    print('Commencing restoration from backup drive. Please standby')
                    tm.sleep(1)
                    print(f'.')
                    tm.sleep(1)
                    print(f'.')
                    tm.sleep(1)
                    print(f'.')
                    tm.sleep(1)
                    print(f'.')
                    tm.sleep(1)
                    print(f'.')
                    tm.sleep(1)
                    print('Restoration complete, please procceed to a safe location for landing to do repairs on main memory.')
                    print('Now commencing last known command. It seems as though we entered into a magnetic anomaly.')
                    userInput = input()#from what
                    if ('What' in userInput) or ('what' in userInput):
                        print('Unknown. As far as the sensors can tell there is nothing here, only empty space. I will however mark this location for future recon.')
                        print('[Scenario end. Action is taken by the crew to temporarily repair the AI memory.]')
                    else:
                        print('Error, invalid interaction.')
                else:
                    print('Error, invalid interaction.')
            else:
                print('Error, invalid interaction.')
    else:
        print('Error, invalid interaction.')
else:
    print('Error, invalid interaction.')
